# %%
# import symbolic capability to Python
from sympy import *
from sympy.abc import *
from sympy.plotting import plot
from IPython.display import display
# print things all pretty
init_printing()

# %% [markdown]
# # Size of the problem: n

# %%
n = symbols("n", positive=True, real=True)

# %% [markdown]
# # Different Functions f with different Time complexity

# %%
f_constant = 20
f_linear = 4 * n + 10
f_linear2 = 10 * n +1
f_quadratic = 1/4 * n**2 + 1/2*n +1 
f_quadratic2 = 1/8 * n**2

# %%
print(f_quadratic2)
# Out:
# 0.125*n**2

# %% [markdown]
# # Definition of Order of Growth (O) ("Big O")
#
# Order of growth (O) is a set of functions whose asymptotic growth behavior is considered equivalent:
#
# Two functions f(n) and g(n) have the equivalent order of growth if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c > 0$ and $c < \infty $.
#
#
# f(n) has a higher order of growth than g(n) if
# $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = \infty $.
#
# f(n) has a smaller order of growth than g(n) if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = 0 $.
#
# $f(n) \in O(g(n))$ if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c < \infty $.

# %% [markdown]
# # Test Order of Growth with the Sympy limit function

# %%
limit(f_quadratic / f_quadratic2, n, oo)
# Out:
# 2.00000000000000

# %%
limit(f_quadratic / f_linear, n, oo)
# Out:
# ∞

# %%
limit( f_linear2 / f_quadratic2, n, oo)
# Out:
# 0

# %% [markdown]
# # Plotting Time Complexity

# %%
expr_range = (n,0,30)
p = plot(
    f_constant,
    f_linear,
    f_quadratic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'



p[0].label = 'constant'
p[1].label = 'linear'
p[2].label = 'quadratic'

p.show()

# %% [markdown]
# # Crossover point

# %%
e1 = Eq(f_quadratic, f_linear)
e1
# Out:
#       2
# 0.25⋅n  + 0.5⋅n + 1 = 4⋅n + 10

# %%
solve(e1, n)
# Out:
# [16.2195444572929]

# %%
solve(e1, n)[0].evalf()
# Out:
# 16.2195444572929

# %% [markdown]
# # Todo

# %%
# TODO: Define 
# - a logarithmic function
# - a log-linear (n log n) function
# - a cubic function
# - an exponential function
# - a factorial function

# %%
f_logarithmic = ln(n)
f_loglinear = n*ln(n)
f_cubic = 1/2*n**3 + 1/4*n**2 + 2*n + 3
f_exponential = 1/2 * 3**n
f_factorial = factorial(n)

# %%
factorial(n)
# Out:
# n!

# %%
# TODO create multiple plots with different combinations of functions
expr_range = (n,0,30)
p = plot(
    f_logarithmic,
    f_loglinear,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'y'
p[1].line_color = 'b'
#p[2].line_color = 'r'




p[0].label = 'logarithmic'
p[1].label = 'loglinear'
#p[2].label = 'cubic'

p.show()

# %%
expr_range = (n,0,30)
p = plot(
    f_cubic,
    f_quadratic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'y'
p[1].line_color = 'r'
#p[2].line_color = 'y'




p[0].label = 'cubic'
p[1].label = 'quadratic'
#p[2].label = 'factorial'

p.show()

# %%
expr_range = (n,0,30)
p = plot(
    f_exponential,
    f_factorial,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'b'
#p[2].line_color = 'y'


p[0].label = 'exponential'
p[1].label = 'factorial'
#p[2].label = 'factorial'

p.show()

# %%
expr_range = (n,0,30)
p = plot(
    f_exponential,
    f_cubic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'r'
#p[2].line_color = 'y'


p[0].label = 'exponential'
p[1].label = 'cubic'
#p[2].label = 'factorial'

p.show()

# %%
# TODO create a log-log plot with your factorial, exponential, quadratic, log-linear, and linear function

functions = [f_factorial, f_exponential, f_quadratic, f_loglinear, f_linear]
func_names = ['factorial', 'exponential', 'quadratic', 'log-linear', 'linear']
expr_range = (n,0,30)
for f in range(len(functions)):
    p = plot(
        f_logarithmic,
        functions[f],
        expr_range,
        show = False,
    legend = True
    );

    p[0].line_color = 'y'
    p[1].line_color = 'c'

    p[0].label = 'logarithmic'
    p[1].label = func_names[f]

    p.show()

# %%
# TODO Calculate one crossover point for two functions

# %%
e2 = Eq(f_logarithmic, f_loglinear)
e2
# Out:
# log(n) = n⋅log(n)

# %%
solve(e2, n)
# Out:
# [1]

# %%
solve(e2, n)[0].evalf()
# Out:
# 1.00000000000000

# %%
e3 = Eq(f_cubic, f_exponential)
e3
# Out:
#      3         2                  n
# 0.5⋅n  + 0.25⋅n  + 2⋅n + 3 = 0.5⋅3

# %%
solve(e3, n)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-55-c08fd910ca7f> in <module>
# ----> 1 solve(e3, n)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1160     ###########################################################################
#    1161     if bare_f:
# -> 1162         solution = _solve(f[0], *symbols, **flags)
#    1163     else:
#    1164         solution = _solve_system(f, symbols, **flags)
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1733
#    1734     if result is False:
# -> 1735         raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1736
#    1737     if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [n, 3**n]
# ...

# %% [markdown]
# Apparently there is no solution when "NotImplementedError" appears: https://groups.google.com/forum/#!topic/sympy/pYh8v0KdBMQ
